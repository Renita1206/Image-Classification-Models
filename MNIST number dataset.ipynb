# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
model=tf.keras.models.Sequential(
    [
     tf.keras.layers.Flatten(input_shape=(28,28)),
     tf.keras.layers.Dense(32,activation='sigmoid'),
     tf.keras.layers.Dense(64,activation='sigmoid'),
     tf.keras.layers.Dense(10,activation='softmax')
    ]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-9225b8732f71> in <module>()
#       8 )
#       9
# ---> 10 model.add( tf.keras.layers.Conv2d(input_shape=(32.32)))
#
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Conv2d'

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_7 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                650
# ...
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
lossS=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
#optimizing techniques examples are sgd and adam, sgd for simple gradient descent
model.compile(optimizer="sgd",loss=lossS,metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train, validation_split=0.33,epochs=15)
# Out:
# Epoch 1/15
# 1257/1257 [==============================] - 2s 2ms/step - loss: 2.1441 - accuracy: 0.3747 - val_loss: 1.6388 - val_accuracy: 0.7303
# Epoch 2/15
# 1257/1257 [==============================] - 2s 2ms/step - loss: 1.4832 - accuracy: 0.7628 - val_loss: 1.0566 - val_accuracy: 0.8188
# Epoch 3/15
# 1257/1257 [==============================] - 2s 1ms/step - loss: 0.9611 - accuracy: 0.8344 - val_loss: 0.7301 - val_accuracy: 0.8602
# Epoch 4/15
# 1257/1257 [==============================] - 2s 2ms/step - loss: 0.7021 - accuracy: 0.8634 - val_loss: 0.5918 - val_accuracy: 0.8727
# Epoch 5/15
# 1257/1257 [==============================] - 2s 2ms/step - loss: 0.5757 - accuracy: 0.8751 - val_loss: 0.5274 - val_accuracy: 0.8764
# Epoch 6/15
# 1257/1257 [==============================] - 2s 2ms/step - loss: 0.5149 - accuracy: 0.8763 - val_loss: 0.4776 - val_accuracy: 0.8782
# Epoch 7/15
# ...

# %%
plt.imshow(x_test[0])
model.predict(x_test)[0]
# Out:
# array([1.7285955e-03, 2.4996419e-04, 3.7917346e-03, 2.2931175e-02,
#        9.5074967e-05, 8.1039005e-04, 3.7120303e-06, 9.5606524e-01,
#        9.1040169e-04, 1.3413681e-02], dtype=float32)

# %%
[i for i in range(len(model.predict(x_test)[0])) if(model.predict(x_test)[0][i]==max(model.predict(x_test)[0]))]
# Out:
# [7]

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()                                                #sgd epoch 25
